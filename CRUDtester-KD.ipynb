# %%
# Kyle Dale
# CS-340-Client/Server Dev
# Professor Sanford
# Project One
# CRUD Tester Scipt
# 7/29 - 7/30


# Import the AnimalShelter class from the Crud_Functionality_Module - KD.py file
from Crud_Functionality_Module_KD import AnimalShelter

# Instantiate the AnimalShelter object using the "aacuser" account credentials
shelter = AnimalShelter()

# Test the CREATE method
data_to_insert = {
    "name": "Georgia",
    "species": "Cat",
    "age": 9
}
insert_result = shelter.create(data_to_insert)
# Check if the insert was successful and print the result
if insert_result:
    print(f"Insert of {data_to_insert['name']} successful!")
else:
    print(f"Insert of {data_to_insert['name']} failed!")

    
# Test the Create method with another animal
data_to_insert = {
    "name": "Fluffy",
    "species": "Cat",
    "age": 3
}
insert_result = shelter.create(data_to_insert)
# Check if the insert was successful and print the result
if insert_result:
    print(f"Insert of {data_to_insert['name']} successful!")
else:
    print(f"Insert of {data_to_insert['name']} failed!")

# Test the Create method with a third animal
data_to_insert = {
    "name": "Speckles",
    "species": "Cat",
    "age": 5
}
insert_result = shelter.create(data_to_insert)
# Check if the insert was successful and print the result
if insert_result:
    print(f"Insert of {data_to_insert['name']} successful!")
else:
    print(f"Insert of {data_to_insert['name']} failed!")
    

# Test the READ method with a key/value lookup pair
query = {"species": "Cat"}
result = shelter.read(query)
# Print the result
print("Read result:")
print(result)


# Test the *update_one* method
query_update_one = {"species": "Cat"}
update_data_one = {"age": 10}
num_modified_one = shelter.update_one(query_update_one, update_data_one)
# Print the number of documents updated
print(f"Number of documents updated (update_one): {num_modified_one}")
# Run the read method after update_one for testing.
query = {"species": "Cat"}
result = shelter.read(query)
print("Read result:")
print(result)


# Test the *update_many* method
query_update_many = {"species": "Cat"}  # Update all documents with species: "Cat"
update_data_many = {"age": 7}  # Set the "age" field to 7 for all matching documents
num_modified_many = shelter.update_many(query_update_many, update_data_many)
# Print the number of documents updated
print(f"Number of documents updated (update_many): {num_modified_many}")
# Run the read method after update_many for testing.
query = {"species": "Cat"}
result = shelter.read(query)
print("Read result:")
print(result)


# Test the *delete_one* method
query_delete_one = {"name": "Fluffy"}
num_deleted_one = shelter.delete_one(query_delete_one)
# Print the number of documents deleted
print(f"Number of documents deleted (delete_one): {num_deleted_one}")
# Run the read method after delete_one for testing.
query = {"species": "Cat"}
result = shelter.read(query)
print("Read result:")
print(result)

# Test the *delete_many* method
query_delete_many = {"species": "Cat"}  # Delete all documents with species: "Cat"
num_deleted_many = shelter.delete_many(query_delete_many)
# Print the number of documents deleted
print(f"Number of documents deleted (delete_many): {num_deleted_many}")
# Run the read method after delete_many for testing.
query = {"species": "Cat"}
result = shelter.read(query)
print("Read result:")
print(result)
# Out:
# Insert of Georgia successful!
# Insert of Fluffy successful!
# Insert of Speckles successful!
# Read result:
# [{'_id': ObjectId('64c57456241694fb010f8f42'), 'name': 'Georgia', 'species': 'Cat', 'age': 9}, {'_id': ObjectId('64c57456241694fb010f8f43'), 'name': 'Fluffy', 'species': 'Cat', 'age': 3}, {'_id': ObjectId('64c57456241694fb010f8f44'), 'name': 'Speckles', 'species': 'Cat', 'age': 5}]
# Number of documents updated (update_one): 1
# Read result:
# [{'_id': ObjectId('64c57456241694fb010f8f42'), 'name': 'Georgia', 'species': 'Cat', 'age': 10}, {'_id': ObjectId('64c57456241694fb010f8f43'), 'name': 'Fluffy', 'species': 'Cat', 'age': 3}, {'_id': ObjectId('64c57456241694fb010f8f44'), 'name': 'Speckles', 'species': 'Cat', 'age': 5}]
# Number of documents updated (update_many): 3
# Read result:
# ...
